# %% [markdown]
# # Numpy Random Package
#
# [Official documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays:
import numpy as np

# Plotting
import matplotlib.pyplot as plt

# %%
# Change default style sheet
plt.style.use('fivethirtyeight')

# Change the default figure size
plt.rcParams['figure.figsize'] = [20, 8]

# %% [markdown]
# Make sure to reference correctly! [1]

# %% [markdown]
# <br>
#
# # numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items
s[:10]
# Out:
# array([ 0.05599176, -0.13612684, -0.11012399, -0.15080351,  0.04968696,
#         0.03347862,  0.18786009, -0.06283587, -0.12093665, -0.02096414])

# %%
abs(mu - np.mean(s))
# Out:
# 0.002315043745364199

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0006553854518586838

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2/(2 * sigma**2))
plt.plot(bins, f, linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## References
#
# [1] https://numpy.org/doc/stable/reference/random/index.html

# %% [markdown]
# ***
#
# ## End
