# %% [markdown]
# # CAO Points 2020 - Excel

# %% [markdown]
# http://www.cao.ie/index.php?page=points&p=2020

# %%
# Import pandas for data frames
import pandas as pd

# Dates and times
import datetime as dt

# For downloading
import urllib.request as urlrq

# %%
# To save the original file to disk

# Get the current date and time
now = dt.datetime.now()

# Format as a string
nowstr = now.strftime('%Y%m%d_%H%M%S')

# Create a file path for the original data
path = 'data/cao2020_' + nowstr + '.xlsx'

# Save original file to disk
urlrq.urlretrieve('http://www2.cao.ie/points/CAOPointsCharts2020.xlsx', path)
# Out:
# ('data/cao2020_20211101_195252.xlsx',
#  <http.client.HTTPMessage at 0x17d51349850>)

# %%
# Download and parse the excel spreadsheet to a data frame

# Excel file contains a lot of unnecessary data like the header part (rows 1 - 9)
# Can be manually removed (and save file locally) or use pandas to remove unnecessary content
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# skiprows: Line numbers to skip (0-indexed) or number of lines to skip (int) at the start of the file. 

df = pd.read_excel('http://www2.cao.ie/points/CAOPointsCharts2020.xlsx', skiprows=10)

# %%
df
# Out:
#                        CATEGORY (i.e.ISCED description)  \
# 0                           Business and administration
# 1                         Humanities (except languages)
# 2                                                  Arts
# 3                                                  Arts
# 4                                                  Arts
# ...                                                 ...
# 1459                       Manufacturing and processing
# 1460  Information and Communication Technologies (ICTs)
# 1461  Information and Communication Technologies (ICTs)
# 1462                                  Personal services
# 1463                 Engineering and engineering trades
#
#                                            COURSE TITLE COURSE CODE2  \
# 0                                International Business        AC120
# 1                                          Liberal Arts        AC137
# 2      First Year Art & Design (Common Entry,portfolio)        AD101
# ...

# %%
# To spotcheck row 765 on excel = 753 in data frame
# (removed first 10, ignore header row, data frame starts counting from 0 rather than 1 in Excel)

df.iloc[753]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Road Transport Technology and Management
# COURSE CODE2                                                           LC286
# R1 POINTS                                                                264
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      264
# EOS Random *                                                             NaN
# EOS Mid-point                                                            360
# LEVEL                                                                      7
# HEI                                         Limerick Institute of Technology
# ...

# %%
# To spotcheck very last row
df.iloc[-1]
# Out:
# CATEGORY (i.e.ISCED description)          Engineering and engineering trades
# COURSE TITLE                        Mechanical and Manufacturing Engineering
# COURSE CODE2                                                           WD230
# R1 POINTS                                                                253
# R1 Random *                                                              NaN
# R2 POINTS                                                                NaN
# R2 Random*                                                               NaN
# EOS                                                                      253
# EOS Random *                                                             NaN
# EOS Mid-point                                                            369
# LEVEL                                                                      8
# HEI                                        Waterford Institute of Technology
# ...

# %%
# Create a file path for the pandas data
pathpd = 'data/cao2020_' + nowstr + '.csv'

# %%
#Save pandas data frame to disk

df.to_csv(pathpd)
